# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import sklearn.tree as tree
import sklearn.model_selection as ms
import sklearn.metrics as metrics

# %%
data = pd.read_csv('data/full.csv')

# %%
data['GW_MEAS_DATE'] = pd.to_numeric(pd.to_datetime(data['GW_MEAS_DATE']))

# %%
from collections import Counter

# Create a Counter object for the WID column.
counter = Counter(data['WID'])

# Create a list of WID values that have 100 or more depth samples.
wids = []
for i in counter.items():
    if i[1] >= 100:
        wids.append(i[0])

# %%
model = tree.DecisionTreeRegressor(max_depth=4)

# %%
well = data[data['WID'] == wids[0]]

# %%
x_cols = ['GW_MEAS_DATE', 'PRCP', 'TMAX', 'TMIN', 'ELEVATION']
y_cols = ['DEPTH']

# %%
well = well[x_cols+y_cols].reset_index(drop=True)

# %%
x_train, x_test, y_train, y_test = ms.train_test_split(well[x_cols], well[y_cols], test_size=0.2)

# %%
model.fit(x_train, y_train)

y_pred = model.predict(x_test)

# %%
r2 = metrics.r2_score(y_test, y_pred)
adj_r2 = 1 - (1 - r2) * (len(y_test) - 1) / (len(y_test) - len(x_test.columns))
mae = metrics.mean_absolute_error(y_test, y_pred)
mse = metrics.mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)

# %%
print('R2:', r2)
print('Adjusted R2:', adj_r2)
print('MAE:', mae)
print('MSE:', mse)
print('RMSE:', rmse)
# Out:
# R2: 0.945730563919186
# Adjusted R2: 0.9425845096536315
# MAE: 1.2340879455691358
# MSE: 2.465789258199417
# RMSE: 1.5702831777101278

# %%
r2
# Out:
# 0.9032089194126874

# %%
adj_r2
# Out:
# 0.8975978422771911

# %%
from scipy import stats
from itertools import combinations

cols = ['GW_MEAS_DATE', 'PRCP', 'TMAX', 'TMIN', 'ELEVATION']

# Create blank dataframe for the evaluations.
blank = pd.DataFrame(columns=['WID','R2','ADJ_R2','MAE','MSE','RMSE'])

f_res = pd.DataFrame(columns=['PARA','R2','ADJ_R2','MAE','MSE','RMSE'])
f_res_count = 0

t_count = 31

for n in range(1, 6):
        # Load linear regression model.
        model = tree.DecisionTreeRegressor(max_depth=6)
        combos = list(combinations(cols, n))
        for para in combos:
                parameters = list(para)
                para_id = "['{}']".format("', '".join(parameters))
                
                # Copy the blank dataframe to the results dataframe.
                res = blank.copy()

                # Set count for results dataframe.
                res_count = 0

                # Loop through the WID values. These have 100 or more DEPTH samples.
                for j in wids:
                        try:
                                # Create temp dataframe from the blank dataframe to store specific well evaluation results.
                                tdf = blank.copy()

                                # Set count for temp dataframe.
                                tdf_count = 0

                                # Create subset of the data dataframe for the specific well.
                                df = data[data['WID'] == j].copy()

                                # Sort Date values
                                df.sort_values(by='GW_MEAS_DATE', inplace=True)

                                df.reset_index(drop=True, inplace=True)

                                # Loop through model processing 3 times to get an average of the results.
                                for n in range(3):

                                        x_train, x_test, y_train, y_test = ms.train_test_split(
                                                df[parameters], df['DEPTH'], test_size=0.2
                                                )

                                        #x_train = x_train.to_numpy().reshape(-1, 1)
                                        #x_test = x_test.to_numpy().reshape(-1, 1)
                                        y_train = y_train.to_numpy()
                                        y_test = y_test.to_numpy()

                                        model.fit(x_train, y_train)

                                        y_pred = model.predict(x_test)

                                        r2 = metrics.r2_score(y_test, y_pred)
                                        adj_r2 = 1 - (1 - r2) * (len(y_test) - 1) / (len(y_test) - len(x_test.columns))
                                        mae = metrics.mean_absolute_error(y_test, y_pred)
                                        mse = metrics.mean_squared_error(y_test, y_pred)
                                        rmse = np.sqrt(mse)

                                        tdf.loc[tdf_count] = [j, r2, adj_r2, mae, mse, rmse]
                                        tdf_count += 1

                                # Add the temp dataframe to the results dataframe.
                                tdf = tdf.mean(numeric_only=True).to_frame().T.reset_index().rename(columns={'index':'WID'})
                                tdf['WID'] = j
                                res.loc[res_count] = tdf.loc[0]
                                res_count += 1
                                
                        except:
                                print(f'{j} failed')
                                continue

                # Add the results dataframe to the final results dataframe.
                res_mean = res.mean(numeric_only=True).to_frame().T.reset_index().rename(columns={'index':'PARA'})
                res_mean['PARA'] = para_id
                f_res.loc[f_res_count] = res_mean.loc[0]
                f_res_count += 1
                pct = (f_res_count / t_count) * 100
                print(f'{pct:.2f}%')
# Out:
# 3.23%
# 6.45%
# 9.68%
# 12.90%
# 16.13%
# 19.35%
# 22.58%
# 25.81%
# 29.03%
# 32.26%
# 35.48%
# 38.71%
# 41.94%
# 45.16%
# 48.39%
# 51.61%
# 54.84%
# 58.06%
# 61.29%
# 64.52%
# 67.74%
# 70.97%
# 74.19%
# 77.42%
# 80.65%
# 83.87%
# 87.10%
# 90.32%
# 93.55%
# 96.77%
# 100.00%

# %%
f_res
# Out:
#                                                  PARA        R2    ADJ_R2  \
# 0                                    ['GW_MEAS_DATE']  0.153451  0.153451
# 1                                            ['PRCP'] -0.208902 -0.208902
# 2                                            ['TMAX'] -0.427099 -0.427099
# 3                                            ['TMIN'] -0.417447 -0.417447
# 4                                       ['ELEVATION'] -0.054023 -0.054023
# 5                            ['GW_MEAS_DATE', 'PRCP']  0.519917  0.501005
# 6                            ['GW_MEAS_DATE', 'TMAX']  0.701079  0.691553
# 7                            ['GW_MEAS_DATE', 'TMIN']  0.438453  0.416967
# 8                       ['GW_MEAS_DATE', 'ELEVATION']  0.712696  0.703664
# 9                                    ['PRCP', 'TMAX'] -0.551904 -0.604640
# 10                                   ['PRCP', 'TMIN'] -0.356567 -0.401645
# 11                              ['PRCP', 'ELEVATION'] -0.181030 -0.218929
# 12                                   ['TMAX', 'TMIN'] -1.230634 -1.315094
# 13                              ['TMAX', 'ELEVATION'] -0.425690 -0.474464
# 14                              ['TMIN', 'ELEVATION'] -0.332369 -0.377542
# 15                   ['GW_MEAS_DATE', 'PRCP', 'TMAX']  0.661178  0.639102
# 16                   ['GW_MEAS_DATE', 'PRCP', 'TMIN']  0.347214  0.291156
# 17              ['GW_MEAS_DATE', 'PRCP', 'ELEVATION']  0.745923  0.729173
# 18                   ['GW_MEAS_DATE', 'TMAX', 'TMIN']  0.199232  0.124581
# 19              ['GW_MEAS_DATE', 'TMAX', 'ELEVATION']  0.410969  0.360692
# 20              ['GW_MEAS_DATE', 'TMIN', 'ELEVATION']  0.152316  0.074150
# 21                           ['PRCP', 'TMAX', 'TMIN'] -0.675433 -0.793399
# 22                      ['PRCP', 'TMAX', 'ELEVATION'] -0.644231 -0.763201
# 23                      ['PRCP', 'TMIN', 'ELEVATION'] -0.589821 -0.707480
# 24                      ['TMAX', 'TMIN', 'ELEVATION'] -0.986673 -1.138717
# 25           ['GW_MEAS_DATE', 'PRCP', 'TMAX', 'TMIN']  0.622671  0.584728
# 26      ['GW_MEAS_DATE', 'PRCP', 'TMAX', 'ELEVATION']  0.665461  0.630342
# 27      ['GW_MEAS_DATE', 'PRCP', 'TMIN', 'ELEVATION']  0.427119  0.349068
# 28      ['GW_MEAS_DATE', 'TMAX', 'TMIN', 'ELEVATION']  0.454054  0.382207
# 29              ['PRCP', 'TMAX', 'TMIN', 'ELEVATION'] -1.604510 -1.950123
# 30  ['GW_MEAS_DATE', 'PRCP', 'TMAX', 'TMIN', 'ELEV...  0.372804  0.246872
#
#          MAE        MSE      RMSE
# 0   0.977158   9.833199  1.871986
# 1   4.074467  46.505119  5.452131
# 2   4.329969  52.144609  5.786183
# 3   4.132182  47.566710  5.550357
# 4   3.922257  41.566509  5.136541
# 5   0.980099   9.720639  1.925821
# 6   0.998982   8.412583  1.876464
# 7   1.014672  10.350367  1.987032
# 8   0.944348   8.107384  1.838147
# 9   4.341037  52.705466  5.851645
# 10  4.200525  49.670352  5.666228
# 11  4.051079  44.217156  5.338033
# 12  4.455111  56.865780  6.122932
# 13  4.235985  48.697291  5.630901
# 14  4.151157  47.759803  5.548355
# 15  1.021807   9.468280  1.982266
# 16  1.040640  10.102458  2.023278
# 17  0.956801   9.085489  1.836905
# 18  1.041468   9.857389  2.000908
# 19  1.030740   9.882596  2.006316
# 20  1.053043  11.222226  2.064356
# 21  4.582413  59.500661  6.241759
# 22  4.308539  51.329424  5.783669
# 23  4.260960  51.222923  5.729308
# 24  4.465418  56.115729  6.100163
# 25  1.068887  10.727807  2.035377
# 26  1.037114   9.922872  1.998134
# 27  1.045642  10.544744  2.047188
# 28  1.023472  10.040408  2.001735
# 29  4.489521  59.559846  6.177763
# 30  1.059978  10.912512  2.050952

# %%
f_res
# Out:
#                                                  PARA        R2    ADJ_R2  \
# 0                                    ['GW_MEAS_DATE']  0.572102  0.555723
# 1                                            ['PRCP'] -0.200991 -0.239687
# 2                                            ['TMAX'] -0.476276 -0.527353
# 3                                            ['TMIN'] -0.343491 -0.388941
# 4                                       ['ELEVATION'] -0.049085 -0.083285
# 5                            ['GW_MEAS_DATE', 'PRCP']  0.583523  0.550102
# 6                            ['GW_MEAS_DATE', 'TMAX']  0.475922  0.433543
# 7                            ['GW_MEAS_DATE', 'TMIN']  0.531526  0.494517
# 8                       ['GW_MEAS_DATE', 'ELEVATION']  0.433760  0.383963
# 9                                    ['PRCP', 'TMAX'] -0.537147 -0.646249
# 10                                   ['PRCP', 'TMIN'] -0.495133 -0.601679
# 11                              ['PRCP', 'ELEVATION'] -0.202070 -0.282180
# 12                                   ['TMAX', 'TMIN'] -1.184929 -1.355841
# 13                              ['TMAX', 'ELEVATION'] -0.464414 -0.569540
# 14                              ['TMIN', 'ELEVATION'] -0.373621 -0.471115
# 15                   ['GW_MEAS_DATE', 'PRCP', 'TMAX']  0.384028  0.300420
# 16                   ['GW_MEAS_DATE', 'PRCP', 'TMIN']  0.367779  0.280051
# 17              ['GW_MEAS_DATE', 'PRCP', 'ELEVATION']  0.432043  0.354530
# 18                   ['GW_MEAS_DATE', 'TMAX', 'TMIN']  0.384503  0.301289
# 19              ['GW_MEAS_DATE', 'TMAX', 'ELEVATION']  0.660172  0.625502
# 20              ['GW_MEAS_DATE', 'TMIN', 'ELEVATION']  0.435932  0.358429
# 21                           ['PRCP', 'TMAX', 'TMIN'] -0.895228 -1.117493
# 22                      ['PRCP', 'TMAX', 'ELEVATION'] -0.564553 -0.739474
# 23                      ['PRCP', 'TMIN', 'ELEVATION'] -0.440142 -0.596782
# 24                      ['TMAX', 'TMIN', 'ELEVATION'] -0.905309 -1.126235
# 25           ['GW_MEAS_DATE', 'PRCP', 'TMAX', 'TMIN']  0.473980  0.379470
# 26      ['GW_MEAS_DATE', 'PRCP', 'TMAX', 'ELEVATION']  0.494604  0.406983
# 27      ['GW_MEAS_DATE', 'PRCP', 'TMIN', 'ELEVATION']  0.483851  0.390596
# 28      ['GW_MEAS_DATE', 'TMAX', 'TMIN', 'ELEVATION']  0.460208  0.362722
# 29              ['PRCP', 'TMAX', 'TMIN', 'ELEVATION'] -0.863373 -1.166895
# 30  ['GW_MEAS_DATE', 'PRCP', 'TMAX', 'TMIN', 'ELEV...  0.334811  0.162886
#
#          MAE        MSE      RMSE
# 0   0.955876   9.037452  1.862853
# 1   4.051790  45.325931  5.382292
# 2   4.297970  50.148077  5.726227
# 3   4.188728  48.803469  5.577627
# 4   3.897397  40.226032  5.079521
# 5   0.966428   9.299028  1.898785
# 6   1.033341  10.055431  2.019439
# 7   1.020559  10.069598  1.991688
# 8   0.953101   9.121592  1.864729
# 9   4.329030  51.884627  5.811943
# 10  4.257987  51.456141  5.753941
# 11  4.060292  45.113512  5.380920
# 12  4.478889  56.794988  6.123313
# 13  4.266864  49.527494  5.690047
# 14  4.202202  49.092322  5.603780
# 15  1.034503   9.921177  2.005216
# 16  1.037958  10.538202  2.020682
# 17  0.974636   9.461229  1.905965
# 18  1.068824  10.568289  2.064877
# 19  1.032947  10.055494  2.002649
# 20  1.013746   9.817624  1.972484
# 21  4.479130  57.498069  6.122883
# 22  4.347777  52.831623  5.859499
# 23  4.268915  51.666797  5.763390
# 24  4.492572  57.101206  6.126508
# 25  1.058702  10.280149  2.037260
# 26  1.043534   9.883692  2.004917
# 27  1.031916  10.297650  2.010539
# 28  1.070013  10.930926  2.081060
# 29  4.479003  57.137467  6.106818
# 30  1.062720  10.475873  2.040367

# %%
f_res = f_res.sort_values(by='ADJ_R2', ascending=False).reset_index(drop=True)

# %%
f_res
# Out:
#                                                  PARA        R2    ADJ_R2  \
# 0               ['GW_MEAS_DATE', 'TMAX', 'ELEVATION']  0.660172  0.625502
# 1                                    ['GW_MEAS_DATE']  0.572102  0.555723
# 2                            ['GW_MEAS_DATE', 'PRCP']  0.583523  0.550102
# 3                            ['GW_MEAS_DATE', 'TMIN']  0.531526  0.494517
# 4                            ['GW_MEAS_DATE', 'TMAX']  0.475922  0.433543
# 5       ['GW_MEAS_DATE', 'PRCP', 'TMAX', 'ELEVATION']  0.494604  0.406983
# 6       ['GW_MEAS_DATE', 'PRCP', 'TMIN', 'ELEVATION']  0.483851  0.390596
# 7                       ['GW_MEAS_DATE', 'ELEVATION']  0.433760  0.383963
# 8            ['GW_MEAS_DATE', 'PRCP', 'TMAX', 'TMIN']  0.473980  0.379470
# 9       ['GW_MEAS_DATE', 'TMAX', 'TMIN', 'ELEVATION']  0.460208  0.362722
# 10              ['GW_MEAS_DATE', 'TMIN', 'ELEVATION']  0.435932  0.358429
# 11              ['GW_MEAS_DATE', 'PRCP', 'ELEVATION']  0.432043  0.354530
# 12                   ['GW_MEAS_DATE', 'TMAX', 'TMIN']  0.384503  0.301289
# 13                   ['GW_MEAS_DATE', 'PRCP', 'TMAX']  0.384028  0.300420
# 14                   ['GW_MEAS_DATE', 'PRCP', 'TMIN']  0.367779  0.280051
# 15  ['GW_MEAS_DATE', 'PRCP', 'TMAX', 'TMIN', 'ELEV...  0.334811  0.162886
# 16                                      ['ELEVATION'] -0.049085 -0.083285
# 17                                           ['PRCP'] -0.200991 -0.239687
# 18                              ['PRCP', 'ELEVATION'] -0.202070 -0.282180
# 19                                           ['TMIN'] -0.343491 -0.388941
# 20                              ['TMIN', 'ELEVATION'] -0.373621 -0.471115
# 21                                           ['TMAX'] -0.476276 -0.527353
# 22                              ['TMAX', 'ELEVATION'] -0.464414 -0.569540
# 23                      ['PRCP', 'TMIN', 'ELEVATION'] -0.440142 -0.596782
# 24                                   ['PRCP', 'TMIN'] -0.495133 -0.601679
# 25                                   ['PRCP', 'TMAX'] -0.537147 -0.646249
# 26                      ['PRCP', 'TMAX', 'ELEVATION'] -0.564553 -0.739474
# 27                           ['PRCP', 'TMAX', 'TMIN'] -0.895228 -1.117493
# 28                      ['TMAX', 'TMIN', 'ELEVATION'] -0.905309 -1.126235
# 29              ['PRCP', 'TMAX', 'TMIN', 'ELEVATION'] -0.863373 -1.166895
# 30                                   ['TMAX', 'TMIN'] -1.184929 -1.355841
#
#          MAE        MSE      RMSE
# 0   1.032947  10.055494  2.002649
# 1   0.955876   9.037452  1.862853
# 2   0.966428   9.299028  1.898785
# 3   1.020559  10.069598  1.991688
# 4   1.033341  10.055431  2.019439
# 5   1.043534   9.883692  2.004917
# 6   1.031916  10.297650  2.010539
# 7   0.953101   9.121592  1.864729
# 8   1.058702  10.280149  2.037260
# 9   1.070013  10.930926  2.081060
# 10  1.013746   9.817624  1.972484
# 11  0.974636   9.461229  1.905965
# 12  1.068824  10.568289  2.064877
# 13  1.034503   9.921177  2.005216
# 14  1.037958  10.538202  2.020682
# 15  1.062720  10.475873  2.040367
# 16  3.897397  40.226032  5.079521
# 17  4.051790  45.325931  5.382292
# 18  4.060292  45.113512  5.380920
# 19  4.188728  48.803469  5.577627
# 20  4.202202  49.092322  5.603780
# 21  4.297970  50.148077  5.726227
# 22  4.266864  49.527494  5.690047
# 23  4.268915  51.666797  5.763390
# 24  4.257987  51.456141  5.753941
# 25  4.329030  51.884627  5.811943
# 26  4.347777  52.831623  5.859499
# 27  4.479130  57.498069  6.122883
# 28  4.492572  57.101206  6.126508
# 29  4.479003  57.137467  6.106818
# 30  4.478889  56.794988  6.123313

# %%
f_res
# Out:
#                                                  PARA        R2    ADJ_R2  \
# 0               ['GW_MEAS_DATE', 'PRCP', 'ELEVATION']  0.745923  0.729173
# 1                       ['GW_MEAS_DATE', 'ELEVATION']  0.712696  0.703664
# 2                            ['GW_MEAS_DATE', 'TMAX']  0.701079  0.691553
# 3                    ['GW_MEAS_DATE', 'PRCP', 'TMAX']  0.661178  0.639102
# 4       ['GW_MEAS_DATE', 'PRCP', 'TMAX', 'ELEVATION']  0.665461  0.630342
# 5            ['GW_MEAS_DATE', 'PRCP', 'TMAX', 'TMIN']  0.622671  0.584728
# 6                            ['GW_MEAS_DATE', 'PRCP']  0.519917  0.501005
# 7                            ['GW_MEAS_DATE', 'TMIN']  0.438453  0.416967
# 8       ['GW_MEAS_DATE', 'TMAX', 'TMIN', 'ELEVATION']  0.454054  0.382207
# 9               ['GW_MEAS_DATE', 'TMAX', 'ELEVATION']  0.410969  0.360692
# 10      ['GW_MEAS_DATE', 'PRCP', 'TMIN', 'ELEVATION']  0.427119  0.349068
# 11                   ['GW_MEAS_DATE', 'PRCP', 'TMIN']  0.347214  0.291156
# 12  ['GW_MEAS_DATE', 'PRCP', 'TMAX', 'TMIN', 'ELEV...  0.372804  0.246872
# 13                                   ['GW_MEAS_DATE']  0.153451  0.153451
# 14                   ['GW_MEAS_DATE', 'TMAX', 'TMIN']  0.199232  0.124581
# 15              ['GW_MEAS_DATE', 'TMIN', 'ELEVATION']  0.152316  0.074150
# 16                                      ['ELEVATION'] -0.054023 -0.054023
# 17                                           ['PRCP'] -0.208902 -0.208902
# 18                              ['PRCP', 'ELEVATION'] -0.181030 -0.218929
# 19                              ['TMIN', 'ELEVATION'] -0.332369 -0.377542
# 20                                   ['PRCP', 'TMIN'] -0.356567 -0.401645
# 21                                           ['TMIN'] -0.417447 -0.417447
# 22                                           ['TMAX'] -0.427099 -0.427099
# 23                              ['TMAX', 'ELEVATION'] -0.425690 -0.474464
# 24                                   ['PRCP', 'TMAX'] -0.551904 -0.604640
# 25                      ['PRCP', 'TMIN', 'ELEVATION'] -0.589821 -0.707480
# 26                      ['PRCP', 'TMAX', 'ELEVATION'] -0.644231 -0.763201
# 27                           ['PRCP', 'TMAX', 'TMIN'] -0.675433 -0.793399
# 28                      ['TMAX', 'TMIN', 'ELEVATION'] -0.986673 -1.138717
# 29                                   ['TMAX', 'TMIN'] -1.230634 -1.315094
# 30              ['PRCP', 'TMAX', 'TMIN', 'ELEVATION'] -1.604510 -1.950123
#
#          MAE        MSE      RMSE
# 0   0.956801   9.085489  1.836905
# 1   0.944348   8.107384  1.838147
# 2   0.998982   8.412583  1.876464
# 3   1.021807   9.468280  1.982266
# 4   1.037114   9.922872  1.998134
# 5   1.068887  10.727807  2.035377
# 6   0.980099   9.720639  1.925821
# 7   1.014672  10.350367  1.987032
# 8   1.023472  10.040408  2.001735
# 9   1.030740   9.882596  2.006316
# 10  1.045642  10.544744  2.047188
# 11  1.040640  10.102458  2.023278
# 12  1.059978  10.912512  2.050952
# 13  0.977158   9.833199  1.871986
# 14  1.041468   9.857389  2.000908
# 15  1.053043  11.222226  2.064356
# 16  3.922257  41.566509  5.136541
# 17  4.074467  46.505119  5.452131
# 18  4.051079  44.217156  5.338033
# 19  4.151157  47.759803  5.548355
# 20  4.200525  49.670352  5.666228
# 21  4.132182  47.566710  5.550357
# 22  4.329969  52.144609  5.786183
# 23  4.235985  48.697291  5.630901
# 24  4.341037  52.705466  5.851645
# 25  4.260960  51.222923  5.729308
# 26  4.308539  51.329424  5.783669
# 27  4.582413  59.500661  6.241759
# 28  4.465418  56.115729  6.100163
# 29  4.455111  56.865780  6.122932
# 30  4.489521  59.559846  6.177763

# %%
from scipy import stats
from itertools import combinations

cols = ['GW_MEAS_DATE', 'PRCP', 'TMAX', 'TMIN', 'ELEVATION']

# Create blank dataframe for the evaluations.
blank = pd.DataFrame(columns=['WID','R2','ADJ_R2','MAE','MSE','RMSE'])

f_res = pd.DataFrame(columns=['PARA','R2','ADJ_R2','MAE','MSE','RMSE'])
f_res_count = 0

t_count = 31

for n in range(1, 6):
        # Load linear regression model.
        model = tree.DecisionTreeRegressor(max_depth=6)
        combos = list(combinations(cols, n))
        for para in combos:
                parameters = list(para)
                para_id = "['{}']".format("', '".join(parameters))
                
                # Copy the blank dataframe to the results dataframe.
                res = blank.copy()

                # Set count for results dataframe.
                res_count = 0

                # Loop through the WID values. These have 100 or more DEPTH samples.
                for j in wids:
                        try:
                                # Create temp dataframe from the blank dataframe to store specific well evaluation results.
                                tdf = blank.copy()

                                # Set count for temp dataframe.
                                tdf_count = 0

                                # Create subset of the data dataframe for the specific well.
                                df = data[data['WID'] == j].copy()

                                # Sort Date values
                                df.sort_values(by='GW_MEAS_DATE', inplace=True)

                                df.reset_index(drop=True, inplace=True)

                                # Loop through model processing 3 times to get an average of the results.
                                for n in range(3):

                                        x_train, x_test, y_train, y_test = ms.train_test_split(
                                                df[parameters], df['DEPTH'], test_size=0.2
                                                )

                                        #x_train = x_train.to_numpy().reshape(-1, 1)
                                        #x_test = x_test.to_numpy().reshape(-1, 1)
                                        y_train = y_train.to_numpy()
                                        y_test = y_test.to_numpy()

                                        model.fit(x_train, y_train)

                                        y_pred = model.predict(x_test)

                                        r2 = metrics.r2_score(y_test, y_pred)
                                        adj_r2 = 1 - (1 - r2) * (len(y_test) - 1) / (len(y_test) - len(x_test.columns))
                                        mae = metrics.mean_absolute_error(y_test, y_pred)
                                        mse = metrics.mean_squared_error(y_test, y_pred)
                                        rmse = np.sqrt(mse)

                                        tdf.loc[tdf_count] = [j, r2, adj_r2, mae, mse, rmse]
                                        tdf_count += 1

                                # Add the temp dataframe to the results dataframe.
                                tdf = tdf.mean(numeric_only=True).to_frame().T.reset_index().rename(columns={'index':'WID'})
                                tdf['WID'] = j
                                res.loc[res_count] = tdf.loc[0]
                                res_count += 1
                                
                        except:
                                print(f'{j} failed')
                                continue

                # Add the results dataframe to the final results dataframe.
                res_mean = res.mean(numeric_only=True).to_frame().T.reset_index().rename(columns={'index':'PARA'})
                res_mean['PARA'] = para_id
                f_res.loc[f_res_count] = res_mean.loc[0]
                f_res_count += 1
                pct = (f_res_count / t_count) * 100
                print(f'{pct:.2f}%')

# %%
model = tree.DecisionTreeRegressor(max_depth=3)

x_train, x_test, y_train, y_test = ms.train_test_split(data[x_cols], data['WATER_ELEVATION'], test_size=0.2)

# %%
model.fit(x_train, y_train)

y_pred = model.predict(x_test)

# %%
r2 = metrics.r2_score(y_test, y_pred)
adj_r2 = 1 - (1 - r2) * (len(y_test) - 1) / (len(y_test) - len(x_test.columns))
mae = metrics.mean_absolute_error(y_test, y_pred)
mse = metrics.mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)

print(f'R2: {r2}')
print(f'Adjusted R2: {adj_r2}')
print(f'MAE: {mae}')
print(f'MSE: {mse}')
print(f'RMSE: {rmse}')
# Out:
# R2: 0.9680884853502995
# Adjusted R2: 0.9680873648518874
# MAE: 32.74839709735421
# MSE: 2380.268108958048
# RMSE: 48.78799144213715
